# %% [markdown]
# # Final words
#  - Course will stay online after this, feel free to go through at your own pace: <https://bit.ly/data_analysis_course_web>
#  - Please fill out our feedback form (very short, no more than two minutes): <https://bit.ly/arc_trainingfeedback>

# %% [markdown]
# # ARC are here to help
#  - Technical help on projects
#  - University wide (not just computationally intensive departments)
#  - Provide programmers for research projects if built into grant proposals
#  - Hamilton (https://www.dur.ac.uk/arc/hamilton/)
#  - Bede (https://www.dur.ac.uk/arc/bede/)
#  - More training: https://bit.ly/2KwXcrW
#  - Come to Research Methods Café for ad-hoc technical advice (virtual event for now): <https://bit.ly/3eJSkNN>
